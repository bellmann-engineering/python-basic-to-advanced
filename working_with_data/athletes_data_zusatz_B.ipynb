# %%
import pandas as pd

# %%
df = pd.read_csv('athletes.csv', skiprows=0, index_col=0)

# %%
df.head()
# Out:
#                      name nationality     sex date_of_birth  height  weight  \
# id
# 736041664  A Jesus Garcia         ESP    male    1969-10-17    1.72    64.0
# 532037425      A Lam Shin         KOR  female    1986-09-23    1.68    56.0
# 435962603     Aaron Brown         CAN    male    1992-05-27    1.98    79.0
# 521041435      Aaron Cook         MDA    male    1991-01-02    1.83    80.0
# 33922579       Aaron Gate         NZL    male    1990-11-26    1.81    71.0
#
#                sport  gold  silver  bronze info
# id
# 736041664  athletics     0       0       0  NaN
# 532037425    fencing     0       0       0  NaN
# 435962603  athletics     0       0       1  NaN
# 521041435  taekwondo     0       0       0  NaN
# 33922579     cycling     0       0       0  NaN

# %%
df.columns
# Out:
# Index(['name', 'nationality', 'sex', 'date_of_birth', 'height', 'weight',
#        'sport', 'gold', 'silver', 'bronze', 'info'],
#       dtype='object')

# %%
df.loc[df['sport'] == 'cycling']
# Out:
#                             name nationality     sex date_of_birth  height  \
# id
# 33922579              Aaron Gate         NZL    male    1990-11-26    1.81
# 285603057  Abderrahmane Mansouri         ALG    male    1995-01-13    1.72
# 184652432             Adam Yates         GBR    male    1992-08-07    1.72
# 664737236      Adrien Niyonshuti         RWA    male    1987-01-02    1.65
# 696999235            Ahmet Orken         TUR    male    1993-03-12    1.77
# ...                          ...         ...     ...           ...     ...
# 116013385          Yuta Wakimoto         JPN    male    1989-03-21    1.81
# 503085577           Zac Williams         NZL    male    1995-07-21    1.80
# 538896901          Zdenek Stybar         CZE    male    1985-12-11    1.83
# 989437678         Zhao Juan Meng         HKG  female    1989-12-14    1.70
# 448660080              Zhen Wang         CHN    male    1989-06-26    1.72
#
#            weight    sport  gold  silver  bronze info
# id
# ...

# %%
df.loc[df['gold'] > 0]
# Out:
#                            name nationality     sex date_of_birth  height  \
# id
# 162792594        Abbey Weitzeil         USA  female    1996-12-03    1.78
# 746318262  Abdulrashid Sadulaev         RUS    male    1996-05-09    1.77
# 561951036            Adam Peaty         GBR    male    1994-12-28    1.93
# 638298176      Agustin Mazzilli         ARG    male    1989-06-20    1.73
# 213448220       Ahmad Abughaush         JOR    male    1996-02-01    1.78
# ...                         ...         ...     ...           ...     ...
# 51119392          Yusuke Tanaka         JPN    male    1989-11-29    1.66
# 879954351                  Zeca         BRA    male    1994-05-16    1.70
# 920733515             Zhen Wang         CHN    male    1991-08-24    1.75
# 334126873           Zhiyong Shi         CHN    male    1993-10-10    1.68
# 593183472           Zivko Gocic         SRB    male    1982-08-22    1.93
#
#            weight          sport  gold  silver  bronze info
# id
# ...
